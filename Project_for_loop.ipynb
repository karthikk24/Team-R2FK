# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
from pprint import pprint

# %%
url = "https://api.nasa.gov/neo/rest/v1/neo/browse?api_key=gzBvVGiFEKMOUKe2a3RX0xNX9RPoGbz1x53zQSN1"
units = "metric"

# %%
response=requests.get(url).json()
pprint(response)
# Out:
# {'links': {'next': 'https://api.nasa.gov/neo/rest/v1/neo/browse?page=1&size=20&api_key=gzBvVGiFEKMOUKe2a3RX0xNX9RPoGbz1x53zQSN1',
#            'self': 'https://api.nasa.gov/neo/rest/v1/neo/browse?page=0&size=20&api_key=gzBvVGiFEKMOUKe2a3RX0xNX9RPoGbz1x53zQSN1'},
#  'near_earth_objects': [{'absolute_magnitude_h': 16.1,
#                          'close_approach_data': [{'close_approach_date': '1945-06-07',
#                                                   'epoch_date_close_approach': -775328400000,
#                                                   'miss_distance': {'astronomical': '0.0334251035',
#                                                                     'kilometers': '5000324.5',
#                                                                     'lunar': '13.0023651123',
#                                                                     'miles': '3107057.5'},
#                                                   'orbiting_body': 'Mars',
# ...

# %%
#name = response['near_earth_objects'][1]['is_potentially_hazardous_asteroid']

# %%
#name

# %%
#response = pd.DataFrame(response)
#for x in range(len(repsonse))

# %%
name_page =[]
danger = []
#pd.DataFrame(response)
for x in range(len(response['near_earth_objects'])):
    name_page.append(response['near_earth_objects'][x]['name'])

# %%
name_page
# Out:
# ['21277 (1996 TO5)',
#  '162038 (1996 DH)',
#  '189058 (2000 UT16)',
#  '276274 (2002 SS41)',
#  '322913 (2002 CM1)',
#  '435730 (2008 UK90)',
#  '451297 (2010 TK54)',
#  '452307 Manawydan (1997 XV11)',
#  '452421 (2002 VX99)',
#  '453100 (2007 WU4)',
#  '454266 (2014 FM7)',
#  '(1979 XB)',
#  '(1990 UN)',
#  '(1991 XA)',
#  '(1992 YD3)',
#  '(1993 BD3)',
#  '(1993 BU3)',
#  '(1994 FA)',
#  '(1994 GK)',
#  '(1994 RB)']

# %%
for x in range(len(response['near_earth_objects'])):
    danger.append(response['near_earth_objects'][x]['is_potentially_hazardous_asteroid'])

# %%
danger
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
abs_mag =[]
for x in range(len(response['near_earth_objects'])):
    abs_mag.append(response['near_earth_objects'][x]['absolute magnitude (miles)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-4eee491345f4> in <module>()
#       1 abs_mag =[]
#       2 for x in range(len(response['near_earth_objects'])):
# ----> 3     abs_mag.append(response['near_earth_objects'][x]['absolute magnitude (miles)'])
#
# KeyError: 'absolute magnitude (miles)'
